# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from tqdm import tqdm

# %%
def parse_data(file):
    """
    Parse saved csv data file each column as individual arrays
    
    Parameters
    ----------
    file: string
        string to the datafile pathname
    """

    data = np.loadtxt(file, delimiter=",")
    data = np.array([data[:, i] for i in range(data.shape[1])])
    return data

# %%
label_array = ["Inside temperature (bottom)", "Inside temperature (top)", "Outside temperature", "CO2 concentration",
               "Humidity RH inside", "Heater current","Heater voltage","Set point temperature","H2 TVOC raw reading",
              "EthOH TVOC raw reading"]
y_axis_labels = ["Temperature (C)","CO2 concentration (ppm)","Relative Humidity (%)","Current (A)","Voltage (V)",
                 "H2 TVOC reading (arb)","EthOH TVOC reading (arb)"]

# %% [markdown]
# # Heater + Fan Testing Plot (Q1)
#
# save_data0.csv: box_1 (cooling fan on)
#
# save_data1.csv: box_2 (cooling fan off)
#
# Heater turned off at 100s

# %%
data0 = parse_data('data_saves/save_data0.csv')
data1 = parse_data('data_saves/save_data1.csv')

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(data0[0][1:], data0[1][1:], label=label_array[0])
ax.plot(data1[0], data1[1], label=label_array[0])
ax.set_ylim(25)
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[0])
ax.set_title('Temperature Testing')
ax.grid()
ax.legend()
fig.savefig('Visualizations/Q1.png')

# %% [markdown]
# # Proportional Terms
#
# ### k_p = 20, k_i = 0, k_d = 0 (Q3)

# %%
data2 = parse_data('data_saves/save_data2.csv')

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(data2[0][1:], data2[1][1:], label=label_array[0])
ax.plot(data2[0][1:], data2[8][1:], label=label_array[7])
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[0])
ax.grid()
ax.legend()
# fig.savefig('Visualizations/Q3.png')

# %% [markdown]
# ### k_p = 1, k_i = 0, k_d = 0 (Q4)

# %%
data3 = parse_data('data_saves/save_data3.csv')

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(data3[0][1:], data3[1][1:], label=label_array[0])
# ax.plot(data3[0][1:], data3[8][1:], label=label_array[7])
ax.plot(data3[0][2:], data3[8][2:], label=label_array[7])
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[0])
ax.grid()
ax.legend()
# fig.savefig('Visualizations/Q4.png')

# %% [markdown]
# # Derivative Term (Q5)

# %%
data4 = parse_data('data_saves/save_data4.csv')

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(data4[0], data4[1], label=label_array[0])
ax.plot(data4[0], data4[8], label=label_array[7])
# ax.plot(data3[0][2:], data3[8][2:], label=label_array[7])
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[0])
ax.grid()
ax.legend()
# fig.savefig('Visualizations/Q5.png')

# %% [markdown]
# # Integral Term (Q6)

# %%
data5 = parse_data('data_saves/save_data5.csv')

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(data5[0], data5[1], label=label_array[0])
ax.plot(data5[0], data5[8], label=label_array[7])
# ax.plot(data3[0][2:], data3[8][2:], label=label_array[7])
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[0])
ax.grid()
ax.legend()
# fig.savefig('Visualizations/Q6.png')

# %% [markdown]
# # Q3 - Q6 Combines Plot

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10), constrained_layout=True)

axes[0, 0].plot(data2[0][1:], data2[1][1:], label=label_array[0])
axes[0, 0].plot(data2[0][1:], data2[8][1:], label=label_array[7])
axes[0, 0].set_xlabel('Time (s)')
axes[0, 0].set_ylabel(y_axis_labels[0])
axes[0, 0].grid()
axes[0, 0].legend()


axes[0, 1].plot(data3[0][1:], data3[1][1:], label=label_array[0])
# ax.plot(data3[0][1:], data3[8][1:], label=label_array[7])
axes[0, 1].plot(data3[0][2:], data3[8][2:], label=label_array[7])
axes[0, 1].set_xlabel('Time (s)')
axes[0, 1].set_ylabel(y_axis_labels[0])
axes[0, 1].grid()
axes[0, 1].legend()


axes[1, 0].plot(data4[0], data4[1], label=label_array[0])
axes[1, 0].plot(data4[0], data4[8], label=label_array[7])
# ax.plot(data3[0][2:], data3[8][2:], label=label_array[7])
axes[1, 0].set_xlabel('Time (s)')
axes[1, 0].set_ylabel(y_axis_labels[0])
axes[1, 0].grid()
axes[1, 0].legend()


axes[1, 1].plot(data5[0], data5[1], label=label_array[0])
axes[1, 1].plot(data5[0], data5[8], label=label_array[7])
# ax.plot(data3[0][2:], data3[8][2:], label=label_array[7])
axes[1, 1].set_xlabel('Time (s)')
axes[1, 1].set_ylabel(y_axis_labels[0])
axes[1, 1].grid()
axes[1, 1].legend()

# Adjust subplot spacing to make room for labels
plt.subplots_adjust(left=0.02, right=0.97, top=1.0, bottom=0.08, wspace=0.2, hspace=0.2)

# Add outer-corner labels
labels = [
    r'(a) $\; K_p = 20.0; K_i = 0.0; K_d = 0.0$',
    r'(b) $\; K_p = 1.0; K_i = 0.0; K_d = 0.0$',
    r'(c) $\; K_p = 5.0; K_i = 0.0; K_d = 10.0$',
    r'(d) $\; K_p = 5.0; K_i = 0.5; K_d = 10.0$'
]

# Coordinates just outside upper-left corner
for ax, label in zip(axes.flatten(), labels):
    ax.text(-0.12, 1.1, label, transform=ax.transAxes,fontsize=20, va='top', ha='left')


fig.savefig('Visualizations/Q3-Q6.png')
# Out:
# /var/folders/2w/fqycdcd16rx2bbmbqszt3w7h0000gn/T/ipykernel_32370/2784249358.py:38: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(left=0.02, right=0.97, top=1.0, bottom=0.08, wspace=0.2, hspace=0.2)

# %% [markdown]
# # CO2 Plot
#
# ## Seperate Plots

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

data6 = parse_data('data_saves/save_data106.csv')

fig, ax1 = plt.subplots(figsize=(8, 5))

ax1.plot(data6[0][1:], data6[1][1:], color=colors[0], label=label_array[0])
ax1.set_xlabel('Time (s)')
ax1.set_ylabel(y_axis_labels[0])
ax1.tick_params(axis='y')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(data6[0], data6[4], color=colors[1], label=label_array[3])
ax2.set_ylabel(y_axis_labels[1])
ax2.tick_params(axis='y')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2)
# fig.savefig('Visualizations/CO2_1.png')

# %%
data7 = parse_data('data_saves/save_data107.csv')

fig, ax1 = plt.subplots(figsize=(8, 5))

ax1.plot(data7[0][1:], data7[1][1:], color=colors[0], label=label_array[0])
ax1.set_xlabel('Time (s)')
ax1.set_ylabel(y_axis_labels[0])
ax1.tick_params(axis='y')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(data7[0], data7[4], color=colors[1], label=label_array[3])
ax2.set_ylabel(y_axis_labels[1])
ax2.tick_params(axis='y')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(
    lines_1 + lines_2,
    labels_1 + labels_2,
    loc='center left',
    bbox_to_anchor=(0.59, 0.85), 
    borderaxespad=0.
)
# fig.savefig('Visualizations/CO2_2.png')

# %% [markdown]
# ## Combined Plot

# %%
fig, ax1 = plt.subplots(figsize=(10, 6.5))

ax1.plot(data6[0][1:], data6[1][1:], color=colors[0], label=f'{label_array[0]} SP = 30')
ax1.plot(data7[0][1:], data7[1][1:], color=colors[2], label=f'{label_array[0]} SP = 45')

ax1.set_xlabel('Time (s)')
ax1.set_ylabel(y_axis_labels[0])
ax1.set_title(r'Combined Temperature and $\text{CO}_2$ Concentrations')
ax1.tick_params(axis='y')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(data6[0], data6[4], color=colors[1], label=f'{label_array[3]} SP = 30')
ax2.plot(data7[0], data7[4], color=colors[3], label=f'{label_array[3]} SP = 45')
ax2.set_ylabel(y_axis_labels[1])
ax2.tick_params(axis='y')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(
    lines_1 + lines_2,
    labels_1 + labels_2,
    loc='center left',
    bbox_to_anchor=(0.59, 0.80), 
    borderaxespad=0.
)
fig.savefig('Visualizations/CO2_12.png')

# %% [markdown]
# ## Another Combined Plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5), constrained_layout=True)

ax1 = axes[0]
ax1.plot(data6[0][1:], data6[1][1:], color=colors[0], label=label_array[0])
ax1.set_xlabel('Time (s)')
ax1.set_ylabel(y_axis_labels[0])
ax1.tick_params(axis='y')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(data6[0], data6[4], color=colors[1], label=label_array[3])
ax2.set_ylabel(y_axis_labels[1])
ax2.tick_params(axis='y')

lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2)


ax3 = axes[1]
ax3.plot(data7[0][1:], data7[1][1:], color=colors[0], label=label_array[0])
# ax3.set_ylim(46)
ax3.set_xlabel('Time (s)')
ax3.set_ylabel(y_axis_labels[0])
ax3.tick_params(axis='y')
ax3.grid(True)

ax4 = ax3.twinx()
ax4.plot(data7[0], data7[4], color=colors[1], label=label_array[3])
ax4.set_ylabel(y_axis_labels[1])
ax4.tick_params(axis='y')

lines_1, labels_1 = ax3.get_legend_handles_labels()
lines_2, labels_2 = ax4.get_legend_handles_labels()
ax3.legend(
    lines_1 + lines_2,
    labels_1 + labels_2,
    loc='center left',
    bbox_to_anchor=(0.54, 0.85), 
    borderaxespad=0.
)

plt.subplots_adjust(left=0.02, right=0.97, top=1.0, bottom=0.08, wspace=0.2, hspace=0.2)

labels = [
    r'(a) $\;\; T_{SP} = 30.0 ^{\circ}C$',
    r'(b) $\;\; T_{SP} = 45.0 ^{\circ}C$'
]

for ax, label in zip(axes.flatten(), labels):
    ax.text(-0.12, 1.1, label, transform=ax.transAxes,fontsize=20, va='top', ha='left')

fig.savefig('Visualizations/CO2.png')
# Out:
# /var/folders/2w/fqycdcd16rx2bbmbqszt3w7h0000gn/T/ipykernel_32370/3309428848.py:43: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(left=0.02, right=0.97, top=1.0, bottom=0.08, wspace=0.2, hspace=0.2)

# %% [markdown]
# ## Linear and Expotnetial Decay Regression

# %%
sp30_max = np.argmax(data6[4])
sp45_max = np.argmax(data7[4])

print(sp30_max)
print(data6[4][sp30_max])

print(sp45_max)
print(data7[4][sp45_max])
# Out:
# 387
# 2251.0
# 353
# 1555.0

# %%
from scipy.optimize import curve_fit

def exp_decay(t, y0, A, k):
    return y0 + A * np.exp(k * t)

def lin_decay(t, y0, m):
    return y0 + m * t

def cutoff(t, y, start_idx, slope_means, slope_stds, snrs, box_size=50, epsilon=10**-12, step=1, snr_cutoff=1.0, slope_cutoff=0.05, method='snr'):
    """
    Determine cutoff of decaying plot with moving average with
    slope as criteria for cut-off
    
    Parameters
    ----------
    t: np.array
        time array
    y: np.array
        CO2 concentration array
    start_idx: int
        index of the max temeprature value, starting point 
        of regression
    box_size: int
        size of moving box
    snr: float
        signal to noise ratio cutoff for regression slope
    """

    n = len(y) # len of data from 
    consecative = 0

    for i in range(start_idx, n - box_size, step): # start from start_idx + box center, end likewise
        box = slice(i, i + box_size)
        t_box = t[box]
        y_box = y[box]

        if method == 'snr':
            # m, b = np.polyfit(t_box, y_box, 1) # linear regression
            m = np.cov(t_box, y_box, ddof=1)[0, 1] / np.var(t_box, ddof=1) # linear regression in terms of covariance and variance
            slopes = np.diff(y_box) / np.diff(t_box) # array of numerical forward differences
            slope_mean = abs(m) # average slope from regression 
            slope_std = np.std(slopes, ddof=1)
            
            if slope_std < epsilon:
                snr = np.inf
            else:
                snr = slope_mean / slope_std

            
            slope_means.append(m)
            slope_stds.append(slope_std)
            snrs.append(snr)

            if snr < snr_cutoff:
                consecative += 1
            else: 
                consecative = 0
            
            if consecative >= 10:
                return i + box_size
            
        if method == 'slope':
            m = np.cov(t_box, y_box, ddof=1)[0, 1] / np.var(t_box, ddof=1)
            slope_mean = abs(m)

            if slope_mean < slope_cutoff:
                consecative += 1
            else: 
                consecative = 0

            if consecative >= 10:
                return i + box_size
        
    return None

# %% [markdown]
# ## Setpoint Temp = 30.0

# %%
slope_means = []
slope_stds = []
snrs = []


cutoff6 = cutoff(data6[0], data6[4], sp30_max, slope_means, slope_stds, snrs, box_size=50, snr_cutoff=0.5, epsilon=10^-12, step=5, method='snr')
print(cutoff6)

# print(slope_means) # debugging
# print(slope_stds)
# print(snrs)

cutoff6 = cutoff(data6[0], data6[4], sp30_max, slope_means, slope_stds, snrs, box_size=50, step=5, slope_cutoff=0.05, method='slope')
print(cutoff6)

# print(slope_means) # debugging
# print(slope_stds)
# print(snrs)
# Out:
# 702
# 1037

# %%
print(data6[0][387])
print(data6[0][702])
print(data6[0][1037])

print(data6[4][387])
print(data6[4][702])
print(data6[4][1037])
# Out:
# 422.283896446228
# 779.5618193149567
# 1151.6451406478882
# 2251.0
# 567.0
# 523.0

# %% [markdown]
# ## Individual Plots

# %%
t_window = data6[0][387:702]
y_window = data6[4][387:702]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(t_window, y_window, label=label_array[3])
ax.plot(t_window, exp_decay(t_rel, *popt), '--k', label=f'exp fit, k={popt[2]:.4f}, r^2={r2:.4f}')
ax.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=f'linear fit, m={popt_lin[1]:.4f}, r^2={r2_lin:.4f}')
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[1])
ax.tick_params(axis='y')
ax.legend()
ax.grid(True)

# %%
t_window = data6[0][387:1037]
y_window = data6[4][387:1037]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(t_window, y_window, label=label_array[3])
ax.plot(t_window, exp_decay(t_rel, *popt), '--k', label=f'exp fit, k={popt[2]:.4f}, r^2={r2:.4f}')
ax.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=f'linear fit, m={popt_lin[1]:.4f}, r^2={r2_lin:.4f}')
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[1])
ax.tick_params(axis='y')
ax.legend()
ax.grid(True)

# %% [markdown]
# ## Setpoint Temp = 45.0

# %%
slope_means = []
slope_stds = []
snrs = []

cutoff7 = cutoff(data7[0], data7[4], sp45_max, slope_means, slope_stds, snrs, box_size=50, snr_cutoff=0.5, epsilon=10^-12, step=5, method='snr')
print(cutoff7)

# print(slope_means) # debugging
# print(slope_stds)
# print(snrs)

slope_means = []
slope_stds = []
snrs = []

cutoff7 = cutoff(data7[0], data7[4], sp45_max, slope_means, slope_stds, snrs, box_size=50, step=5, slope_cutoff=0.05, method='slope')
print(cutoff7)

# print(slope_means) # debugging
# print(slope_stds)
# print(snrs)

slope_means = []
slope_stds = []
snrs = []
# Out:
# 658
# 773

# %%
print(data7[0][353])
print(data7[0][658])
print(data7[0][773])

print(data7[4][353])
print(data7[4][658])
print(data7[4][773])
# Out:
# 383.05132579803467
# 729.0292329788208
# 858.9127087593079
# 1555.0
# 574.0
# 567.0

# %% [markdown]
# ## Plots

# %%
t_window = data7[0][353:623]
y_window = data7[4][353:623]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(t_window, y_window, label=label_array[3])
ax.plot(t_window, exp_decay(t_rel, *popt), '--k', label=f'exp fit, k={popt[2]:.4f}, r^2={r2:.4f}')
ax.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=f'linear fit, m={popt_lin[1]:.4f}, r^2={r2_lin:.4f}')
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[1])
ax.tick_params(axis='y')
ax.legend()
ax.grid(True)

# %%
t_window = data7[0][353:900]
y_window = data7[4][353:900]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(t_window, y_window, label=label_array[3])
ax.plot(t_window, exp_decay(t_rel, *popt), '--k', label=f'exp fit, k={popt[2]:.4f}, r^2={r2:.4f}')
ax.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=f'linear fit, m={popt_lin[1]:.4f}, r^2={r2_lin:.4f}')
ax.set_xlabel('Time (s)')
ax.set_ylabel(y_axis_labels[1])
ax.tick_params(axis='y')
ax.legend()
ax.grid(True)

# %% [markdown]
# ## Combined Plots

# %%
t_window = data6[0][387:702]
y_window = data6[4][387:702]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)

fig, axes = plt.subplots(1, 2, figsize=(16, 6), constrained_layout=True)

ax1 = axes[1]
ax1.plot(t_window, y_window, label=label_array[3])
ax1.plot(t_window, exp_decay(t_rel, *popt), '--k', label=fr'Exp Fit $R^2$={r2:.4f}')
ax1.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=fr'Linear Fit $R^2$={r2_lin:.4f}')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel(y_axis_labels[1])
ax1.tick_params(axis='y')
ax1.legend()
ax1.grid(True)


t_window = data6[0][387:1037]
y_window = data6[4][387:1037]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)

ax2 = axes[0]
ax2.plot(t_window, y_window, label=label_array[3])
ax2.plot(t_window, exp_decay(t_rel, *popt), '--k', label=fr'Exp Fit $R^2$={r2:.4f}')
ax2.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=fr'Linear Fit $R^2$={r2_lin:.4f}')
ax2.set_xlabel('Time (s)')
ax2.set_ylabel(y_axis_labels[1])
ax2.tick_params(axis='y')
ax2.legend()
ax2.grid(True)
plt.subplots_adjust(left=0.02, right=0.97, top=1.0, bottom=0.08, wspace=0.2, hspace=0.2)

labels = [
    r'(a) $\;\;$ Slope Threshold Cutoff',
    r'(b) $\;\;$ SNR Threshold Cutoff'
]

for ax, label in zip(axes.flatten(), labels):
    ax.text(-0.12, 1.1, label, transform=ax.transAxes,fontsize=20, va='top', ha='left')

# fig.savefig('Visualizations/regression_30.png')
# Out:
# /var/folders/2w/fqycdcd16rx2bbmbqszt3w7h0000gn/T/ipykernel_32370/2406658063.py:55: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(left=0.02, right=0.97, top=1.0, bottom=0.08, wspace=0.2, hspace=0.2)

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12), constrained_layout=True)

t_window = data6[0][387:702]
y_window = data6[4][387:702]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)


ax1 = axes[0, 1]
ax1.plot(t_window, y_window, label=label_array[3])
ax1.plot(t_window, exp_decay(t_rel, *popt), '--k', label=fr'Exp Fit $R^2$={r2:.4f}; k={popt[2]:.4f}')
ax1.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=fr'Linear Fit $R^2$={r2_lin:.4f}; m={popt_lin[0]:.4f}')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel(y_axis_labels[1])
ax1.tick_params(axis='y')
ax1.legend()
ax1.grid(True)


t_window = data6[0][387:1037]
y_window = data6[4][387:1037]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)

ax2 = axes[0, 0]
ax2.plot(t_window, y_window, label=label_array[3])
ax2.plot(t_window, exp_decay(t_rel, *popt), '--k', label=fr'Exp Fit $R^2$={r2:.4f}; k={popt[2]:.4f}')
ax2.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=fr'Linear Fit $R^2$={r2_lin:.4f}; m={popt_lin[0]:.4f}')
ax2.set_xlabel('Time (s)')
ax2.set_ylabel(y_axis_labels[1])
ax2.tick_params(axis='y')
ax2.legend()
ax2.grid(True)

t_window = data7[0][353:658]
y_window = data7[4][353:658]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)


ax4 = axes[1, 1]
ax4.plot(t_window, y_window, label=label_array[3])
ax4.plot(t_window, exp_decay(t_rel, *popt), '--k', label=fr'Exp Fit $R^2$={r2:.4f}; k={popt[2]:.4f}')
ax4.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=fr'Linear Fit $R^2$={r2_lin:.4f}; m={popt_lin[0]:.4f}')
ax4.set_xlabel('Time (s)')
ax4.set_ylabel(y_axis_labels[1])
ax4.tick_params(axis='y')
ax4.legend()
ax4.grid(True)


t_window = data7[0][353:773]
y_window = data7[4][353:773]
t_rel = t_window - t_window[0]

popt, pcov = curve_fit(exp_decay, t_rel, y_window, p0=[y_window[-1], y_window[0]-y_window[-1], -0.01])
popt_lin, _ = curve_fit(lin_decay, t_rel, y_window)

y_fit = exp_decay(t_rel, *popt)
residuals = y_window - y_fit
ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_window - np.mean(y_window))**2)
r2 = 1 - (ss_res / ss_tot)

y_fit_lin = lin_decay(t_rel, *popt_lin)
r2_lin = 1 - np.sum((y_window - y_fit_lin)**2) / np.sum((y_window - np.mean(y_window))**2)

ax3 = axes[1, 0]
ax3.plot(t_window, y_window, label=label_array[3])
ax3.plot(t_window, exp_decay(t_rel, *popt), '--k', label=fr'Exp Fit $R^2$={r2:.4f}; k={popt[2]:.4f}')
ax3.plot(t_window, lin_decay(t_rel, *popt_lin), ':k', label=fr'Linear Fit $R^2$={r2_lin:.4f}; m={popt_lin[0]:.4f}')
ax3.set_xlabel('Time (s)')
ax3.set_ylabel(y_axis_labels[1])
ax3.tick_params(axis='y')
ax3.legend()
ax3.grid(True)

plt.subplots_adjust(left=0.02, right=0.97, top=1.0, bottom=0.08, wspace=0.2, hspace=0.2)

labels = [
    r'(a) $\;\; T_{SP} = 30.0 ^{\circ}C \;$ Slope Cutoff',
    r'(b) $\;\; T_{SP} = 30.0 ^{\circ}C \;$ SNR Cutoff',
    r'(c) $\;\; T_{SP} = 45.0 ^{\circ}C \;$ Slope Cutoff',
    r'(d) $\;\; T_{SP} = 45.0 ^{\circ}C \;$ SNR Cutoff'
]

for ax, label in zip(axes.flatten(), labels):
    ax.text(-0.12, 1.1, label, transform=ax.transAxes,fontsize=20, va='top', ha='left')

fig.savefig('Visualizations/regress_combined.png')
# Out:
# /var/folders/2w/fqycdcd16rx2bbmbqszt3w7h0000gn/T/ipykernel_32370/3895447167.py:111: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(left=0.02, right=0.97, top=1.0, bottom=0.08, wspace=0.2, hspace=0.2)
